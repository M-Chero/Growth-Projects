# %% [markdown]
# <a href="https://colab.research.google.com/github/M-Chero/Growth-Projects/blob/main/Attrition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv('HR Employee Attrition.csv')

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
# Specify the categorical columns
categorical_cols = ['BusinessTravel', 'EducationField', 'Department']

# Encode the categorical columns using the OneHotEncoder
encoder = OneHotEncoder(sparse=False)
x_train_encoded = encoder.fit_transform(x_train[categorical_cols])
x_test_encoded = encoder.transform(x_test[categorical_cols])

# Get the feature names from the OneHotEncoder
feature_names = encoder.get_feature_names_out(input_features=categorical_cols)

# Create DataFrames for the encoded training and test data
x_train_encoded = pd.DataFrame(x_train_encoded, columns=feature_names)
x_test_encoded = pd.DataFrame(x_test_encoded, columns=feature_names)

# Calculate the accuracy on the training and test data
acc_train = np.sum(dtc.predict(x_train_encoded) == y_train_encoded) / float(y_train_encoded.size)
acc_test = np.sum(dtc.predict(x_test_encoded) == y_test_encoded) / float(y_test_encoded.size)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-86-ad1ddbf8fc50> in <cell line: 17>()
#      15
#      16 # Calculate the accuracy on the training and test data
# ---> 17 acc_train = np.sum(dtc.predict(x_train_encoded) == y_train_encoded) / float(y_train_encoded.size)
#      18 acc_test = np.sum(dtc.predict(x_test_encoded) == y_test_encoded) / float(y_test_encoded.size)
#
# ...

# %%
# Concatenate the encoded categorical features with the non-categorical features
x_train_final = pd.concat([x_train_encoded, x_train_non_categorical], axis=1)
x_test_final = pd.concat([x_test_encoded, x_test_non_categorical], axis=1)

# Train the DecisionTreeClassifier on the concatenated data
dtc.fit(x_train_final, y_train_encoded)

# Predict on the concatenated training and test data
train_predictions = dtc.predict(x_train_final)
test_predictions = dtc.predict(x_test_final)

# Calculate the accuracy on the training and test data
acc_train = np.sum(train_predictions == y_train_encoded) / float(y_train_encoded.size)
acc_test = np.sum(test_predictions == y_test_encoded) / float(y_test_encoded.size)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-87-193564788a8a> in <cell line: 2>()
#       1 # Concatenate the encoded categorical features with the non-categorical features
# ----> 2 x_train_final = pd.concat([x_train_encoded, x_train_non_categorical], axis=1)
#       3 x_test_final = pd.concat([x_test_encoded, x_test_non_categorical], axis=1)
#       4
#       5 # Train the DecisionTreeClassifier on the concatenated data
#
# NameError: name 'x_train_non_categorical' is not defined

# %%
categorical_cols= df ['BusinessTravel', 'EducationField','Department','Attrition']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('BusinessTravel', 'EducationField', 'Department', 'Attrition')
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.drop(['EmployeeCount', 'EmployeeNumber'], axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'Over18',
#        'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
le=LabelEncoder()
df['Attrition']=le.fit_transform(df ['Attrition'])

# %%
df.head()
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          1      Travel_Rarely       1102                   Sales
# 1   49          0  Travel_Frequently        279  Research & Development
# 2   37          1      Travel_Rarely       1373  Research & Development
# 3   33          0  Travel_Frequently       1392  Research & Development
# 4   27          0      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
# 2                 2          2          Other                        4
# 3                 3          4  Life Sciences                        4
# 4                 2          1        Medical                        1
#
#    Gender  ...  RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# ...

# %%
le=LabelEncoder()
df['BusinessTravel']=le.fit_transform(df ['BusinessTravel'])

# %%
le=LabelEncoder()
df['Department']=le.fit_transform(df ['Department'])

# %%
le=LabelEncoder()
df['EducationField']=le.fit_transform(df ['EducationField'])

# %%
df
# Out:
#       Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0      41          1               2       1102           2                 1
# 1      49          0               1        279           1                 8
# 2      37          1               2       1373           1                 2
# 3      33          0               1       1392           1                 3
# 4      27          0               2        591           1                 2
# ...   ...        ...             ...        ...         ...               ...
# 1465   36          0               1        884           1                23
# 1466   39          0               2        613           1                 6
# 1467   27          0               2        155           1                 4
# 1468   49          0               1       1023           2                 2
# 1469   34          0               2        628           1                 8
#
# ...

# %%
le=LabelEncoder()
df['Gender']=le.fit_transform(df ['Gender'])

# %%
df.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41          1               2       1102           2                 1
# 1   49          0               1        279           1                 8
# 2   37          1               2       1373           1                 2
# 3   33          0               1       1392           1                 3
# 4   27          0               2        591           1                 2
#
#    Education  EducationField  EnvironmentSatisfaction  Gender  ...  \
# 0          2               1                        2       0  ...
# 1          1               1                        3       1  ...
# 2          2               4                        4       1  ...
# 3          4               1                        4       0  ...
# 4          1               3                        1       1  ...
#
#    RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'Over18',
#        'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
y=df['Attrition'] #dependent variable

# %%
columns = ['BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome', 'Education', 'EducationField', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager', 'Age']
x = df[columns]

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y)

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# Create an instance of the OneHotEncoder
encoder = OneHotEncoder()

# Encode the categorical features (x_train)
x_train_encoded = encoder.fit_transform(x_train)

# Create an instance of the LabelEncoder
label_encoder = LabelEncoder()

# Encode the target labels (y_train)
y_train_encoded = label_encoder.fit_transform(y_train)

# Continue with training using the encoded data
dtc = tree.DecisionTreeClassifier()
dtc.fit(x_train_encoded, y_train_encoded)
# Out:
# DecisionTreeClassifier()

# %%
y_predict = dtc.predict(x_train_encoded)  # Make predictions on the training set
y_probability = dtc.predict_proba(x_train_encoded)[:, 1]  # Calculate prediction probabilities for the training set

# %%
df_train = pd.DataFrame(x_train)

# Add the 'Predict' and 'Probability' columns to the new DataFrame
df_train['Predict'] = y_predict
df_train['Probability'] = y_probability

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'Over18',
#        'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df_train.head()
# Out:
#      BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 755               2       1234           2                11          2
# 997               2        135           1                17          4
# 648               1       1231           2                21          2
# 405               2        688           1                 3          3
# 70                1       1225           2                 1          1
#
#      EducationField  EnvironmentSatisfaction  Gender  HourlyRate  \
# 755               1                        4       0          90
# 997               1                        4       0          51
# 648               3                        3       0          54
# 405               3                        1       1          91
# 70                1                        1       0          57
#
#      JobInvolvement  ...  TotalWorkingYears TrainingTimesLastYear  \
# 755               3  ...                 26                     4
# ...

# %%
# Get the feature names from the OneHotEncoder
feature_names = encoder.get_feature_names_out(input_features=categorical_cols)

# Create DataFrames for the encoded training and test data
x_train_encoded = pd.DataFrame(x_train_encoded, columns=feature_names)
x_test_encoded = pd.DataFrame(x_test_encoded, columns=feature_names)

# Calculate the accuracy on the training and test data
acc_train = np.sum(dtc.predict(x_train_encoded) == y_train_encoded) / float(y_train_encoded.size)
acc_test = np.sum(dtc.predict(x_test_encoded) == y_test_encoded) / float(y_test_encoded.size)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-79-804787da751d> in <cell line: 2>()
#       1 # Get the feature names from the OneHotEncoder
# ----> 2 feature_names = encoder.get_feature_names_out(input_features=categorical_cols)
#       3
#       4 # Create DataFrames for the encoded training and test data
#       5 x_train_encoded = pd.DataFrame(x_train_encoded, columns=feature_names)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py in get_feature_names_out(self, input_features)
#    1100         """
#    1101         check_is_fitted(self)
# -> 1102         input_features = _check_feature_names_in(self, input_features)
#    1103         cats = [
#    1104             self._compute_transformed_categories(i)
#
# ...

# %%
acc_train = np.sum(dtc.predict(x_train_encoded)==y_train_encoded)/float(y_train_encoded.size)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-77-6a2f6e746d61> in <cell line: 1>()
# ----> 1 acc_train = np.sum(dtc.predict(x_train_encoded)==y_train_encoded)/float(y_train_encoded.size)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/tree/_classes.py in predict(self, X, check_input)
#     424         """
#     425         check_is_fitted(self)
# --> 426         X = self._validate_X_predict(X, check_input)
#     427         proba = self.tree_.predict(X)
#     428         n_samples = X.shape[0]
#
# /usr/local/lib/python3.10/dist-packages/sklearn/tree/_classes.py in _validate_X_predict(self, X, check_input)
#     390         """Validate the training data on predict (probabilities)."""
#     391         if check_input:
# --> 392             X = self._validate_data(X, dtype=DTYPE, accept_sparse="csr", reset=False)
#     393             if issparse(X) and (
# ...

# %%
acc_train = np.sum(dtc.predict(x_train_encoded)==y_train_encoded)/float(y_train_encoded.size)
acc_test = np.sum(dtc.predict(x_test)==y_test)/float(y_test.size)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-67-3c63e50ffc19> in <cell line: 2>()
#       1 acc_train = np.sum(dtc.predict(x_train_encoded)==y_train_encoded)/float(y_train_encoded.size)
# ----> 2 acc_test = np.sum(dtc.predict(x_test)==y_test)/float(y_test.size)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/tree/_classes.py in predict(self, X, check_input)
#     424         """
#     425         check_is_fitted(self)
# --> 426         X = self._validate_X_predict(X, check_input)
#     427         proba = self.tree_.predict(X)
#     428         n_samples = X.shape[0]
#
# /usr/local/lib/python3.10/dist-packages/sklearn/tree/_classes.py in _validate_X_predict(self, X, check_input)
# ...
